# %% [markdown]
# ## Analyze all single mutant neutralization data
# We generated single mutant reporter virus particles (RVPs) based on DMS differential selection analysis. These RVPs have a GFP based readout that we analyzed via high throughput flow cytometry. Now, we want to determine if single mutations contributed to antibody neutralization resistance or antibody escape. We also want to make figures for the paper.

# %%
# Import packages
import pandas as pd
import os
import numpy as np
from scipy.stats import ttest_ind
from scipy.stats import f_oneway
from IPython.display import HTML, display
from statsmodels.sandbox.stats.multicomp import multipletests
import operator
from functools import reduce

import neutcurve

# %%
# Set pandas display options
pd.set_option('display.float_format', '{:.4g}'.format)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 500)

# %%
## ID sequences and locations
datadir = './data'
resultsdir ='./results'
os.makedirs(datadir, exist_ok = True)
os.makedirs(resultsdir, exist_ok = True)

# ID antibody and experiment number
ab_dict = {'C10': 'CK066',
           'C8': 'CK066',
           'SiGN3C': 'CK066',}

# %% [markdown]
# ### Calculate fraction infectivity
# Based on Kate Crawford's SARS-CoV-2 JID paper, we get calculate fraction infectivity by dividing individual datapoints by the average of no-antibody or no-serum controls.

# %%
neutcurve_ls = []

for antibody in ab_dict:
    # ID sequence
    platereader_datafile = os.path.join(datadir,f'{antibody}_{ab_dict[antibody]}_neutdata.csv')
    platereader = pd.read_csv(platereader_datafile)
    
    # Get list of unique viruses and sort them by the mutated site
    viruses = []
    for item in platereader.columns:
        item = item.split('_')[0]
        if item != antibody:
            if item == 'WT':
                site = 0
            else:
                site = int(item[1:-1])
            viruses.append([item, site])
    viruses = sorted(list(set(tuple(row) for row in viruses)), key=lambda x: x[1])
    viruses = [i[0] for i in viruses]

    # Get list of concentrations
    concentrations = []
    for item in (platereader[f'{antibody}']):
        if item != 'no_ab':
            concentrations.append(item)

    # Caclulate fraction infectivity and then append to neutcurve_ls
    # Get no_ab average to utilize as denominator for fraction infectivity calculation
    # Then divide each value by this denominator
    # Save to reformatted dataframe to be parsed by neutcurve
    for v in viruses:
        rep1 = v + '_1'
        rep2 = v + '_2'
        rep3 = v + '_3'
        replicates = (rep1, rep2, rep3)
        no_ab_average = (platereader[[rep1,rep2,rep3]].loc[platereader[antibody] == 'no_ab'].sum(axis=1)/3).values[0]    
        
        # Add replicate number
        for i in range(0, 3):
            rep = i+1
            
            # Add concentration label
            for n in range(0, len(concentrations)):
                conc = concentrations[n]
                frac_infectivity = platereader[f'{v}_{rep}'][n] / no_ab_average
                
                # Neutcurve doesn't like 0's...?
                if frac_infectivity == 0:
                    frac_infectivity = 0.00000001

                neutcurve_ls.append([antibody, v, rep, conc, float(frac_infectivity)])


# Get dataframe with columns 'serum','virus','replicate','concentration','fraction infectivity'
# neutcurve is set up to accept only columns with these names
neutcurve_df = (pd.DataFrame(data=np.array(neutcurve_ls),
    columns=['serum','virus','replicate','concentration','fraction infectivity'])
                .astype({'fraction infectivity': 'float64', 'concentration': 'float64'})
               )

# %%
neutcurve_df.head(300)
# Out:
#     serum  virus replicate  concentration  fraction infectivity
# 0     C10     WT         1              5                 1e-08
# 1     C10     WT         1              1                 1e-08
# 2     C10     WT         1            0.2                 1e-08
# 3     C10     WT         1           0.04                0.1049
# 4     C10     WT         1          0.008                0.3277
# ..    ...    ...       ...            ...                   ...
# 295    C8  M140T         3       0.000128                0.9148
# 296    C8  M140T         3       2.56e-05                0.9889
# 297    C8  A310D         1             10               0.01639
# 298    C8  A310D         1              2                 1e-08
# 299    C8  A310D         1            0.4                0.0447
#
# [300 rows x 5 columns]

# %% [markdown]
# ### Fit Hill curves to data with neutcurve
# Using the neutcurve documentation, we can produce replicate Hill curves and IC50s for our datasets. With the tables of IC50s, we can perform statistical tests. We can also plot these curves for figures for the paper.

# %%
# Call CurveFits function from neutcurve
fits = neutcurve.CurveFits(neutcurve_df)
fits.replicates
# Out:
# {('C10', 'WT'): ['1', '2', '3', 'average'],
#  ('C10', 'S7P'): ['1', '2', '3', 'average'],
#  ('C10', 'V12I'): ['1', '2', '3', 'average'],
#  ('C10', 'T49D'): ['1', '2', '3', 'average'],
#  ('C10', 'E55Q'): ['1', '2', '3', 'average'],
#  ('C10', 'M140S'): ['1', '2', '3', 'average'],
#  ('C10', 'M206I'): ['1', '2', '3', 'average'],
#  ('C10', 'N478S'): ['1', '2', '3', 'average'],
#  ('C8', 'WT'): ['1', '2', '3', 'average'],
#  ('C8', 'S7P'): ['1', '2', '3', 'average'],
#  ('C8', 'M140T'): ['1', '2', '3', 'average'],
#  ('C8', 'A310D'): ['1', '2', '3', 'average'],
#  ('C8', 'T315K'): ['1', '2', '3', 'average'],
#  ('C8', 'T315Y'): ['1', '2', '3', 'average'],
#  ('C8', 'T315C'): ['1', '2', '3', 'average'],
#  ('C8', 'K373H'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'WT'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'S7P'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'T49D'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'M140T'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'M140G'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'D161E'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'E162Q'): ['1', '2', '3', 'average'],
#  ('SiGN3C', 'E320S'): ['1', '2', '3', 'average'],
#  ('MZ4', 'WT'): ['1', '2', '3', 'average'],
#  ('MZ4', 'G182D'): ['1', '2', '3', 'average'],
#  ('MZ4', 'A248G'): ['1', '2', '3', 'average'],
#  ('MZ4', 'K301H'): ['1', '2', '3', 'average'],
#  ('MZ4', 'T351R'): ['1', '2', '3', 'average'],
#  ('MZ4', 'S368I'): ['1', '2', '3', 'average'],
#  ('MZ4', 'S368N'): ['1', '2', '3', 'average'],
#  ('MZ4', 'S368V'): ['1', '2', '3', 'average'],
#  ('ZV67', 'WT'): ['1', '2', '3', 'average'],
#  ('ZV67', 'A310D'): ['1', '2', '3', 'average'],
#  ('ZV67', 'T315Y'): ['1', '2', '3', 'average'],
#  ('ZV67', 'A333W'): ['1', '2', '3', 'average'],
#  ('ZV67', 'A333R'): ['1', '2', '3', 'average'],
#  ('ZKA64', 'WT'): ['1', '2', '3', 'average'],
#  ('ZKA64', 'T315Y'): ['1', '2', '3', 'average'],
#  ('ZKA64', 'T315C'): ['1', '2', '3', 'average'],
#  ('ZKA64', 'A333R'): ['1', '2', '3', 'average']}

# %%
# Basic serum plots
# fig, axes = fits.plotSera(xlabel = 'concentration (ug/ml)')

# %%
# Custom layout for paper figure
# Color palette
colorwheel = ['#272932', '#5d7ea8', '#9e90a2', '#b6c2d9', '#556da2', '#828489', '#c1c1c1','orange']

# Markers
m = 'o'
fig, axes = fits.plotGrid(
                {
                 # row 1 left: C10 versus T49D
                 (0, 0): ('C10',
                          [{'serum': 'C10', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label':'WT'},
                           {'serum': 'C10', 'virus': 'T49D',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label':'T49D'}]
                          ),
                 # row 1 center: C10 versus WT, S7P, V12I
                 (0, 1): ('C10',
                          [{'serum': 'C10', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label':'WT'},
                           {'serum': 'C10', 'virus': 'S7P',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label':'S7P'},
                           {'serum': 'C10', 'virus': 'V12I',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label':'V12I'}]
                          ),
                 # row 1 right: C10 versus WT, M140S, N478S
                 (0, 2): ('C10',
                          [{'serum': 'C10', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label':'WT'},
                           {'serum': 'C10', 'virus': 'M140S',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label':'M140S'},
                           {'serum': 'C10', 'virus': 'N478S',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label':'N478S'}]
                          ),
                    
                 # row 2 left: C8 versus WT, T315C, T315Y, T315K
                 (1, 0): ('C8',
                          [{'serum': 'C8', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'C8', 'virus': 'T315C',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'T315C'},
                           {'serum': 'C8', 'virus': 'T315Y',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label': 'T315Y'},
                           {'serum': 'C8', 'virus': 'T315K',
                            'replicate': 'average', 'color': colorwheel[3],
                            'marker': m, 'label': 'T315K'}]
                          ),
                 # row 2 center: C8 versus WT, S7P
                 (1, 1): ('C8',
                          [{'serum': 'C8', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'C8', 'virus': 'S7P',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'S7P'}]
                          ),
                 # row 2 right: C8 versus WT, A310D, K373H
                 (1, 2): ('C8',
                          [{'serum': 'C8', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'C8', 'virus': 'A310D',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'A310D'},
                           {'serum': 'C8', 'virus': 'K373H',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label': 'K373H'}]
                          ),

                 # row 3 left: SiGN3C versus WT, T49D
                 (2, 0): ('SiGN3C',
                          [{'serum': 'SiGN3C', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'SiGN3C', 'virus': 'T49D',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'T49D'}]
                          ),
                 # row 3 center: SiGN3C versus WT, S7P
                 (2, 1): ('SiGN3C',
                          [{'serum': 'SiGN3C', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'SiGN3C', 'virus': 'S7P',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'S7P'}]
                          ),
                 # row 3 right: SiGN3C versus WT, E320S
                 (2, 2): ('SiGN3C',
                          [{'serum': 'SiGN3C', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'SiGN3C', 'virus': 'E320S',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'E320S'}]
                          ),
                                  
                 # row 4 left: MZ4 versus WT, T351R, K301H
                 (3, 0): ('MZ4',
                          [{'serum': 'MZ4', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'MZ4', 'virus': 'T351R',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'T351R'},
                           {'serum': 'MZ4', 'virus': 'K301H',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label': 'K301H'}]
                          ),
                 # row 4 center: MZ4 versus WT, G182D
                 (3, 1): ('MZ4',
                          [{'serum': 'MZ4', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'MZ4', 'virus': 'G182D',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'G182D'}]
                          ),
                 # row 4 right: MZ4 versus WT, S368N, S368I, S368V
                 (3, 2): ('MZ4',
                          [{'serum': 'MZ4', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'MZ4', 'virus': 'S368N',
                            'replicate': 'average', 'color': colorwheel[1],
                            'marker': m, 'label': 'S368N'},
                           {'serum': 'MZ4', 'virus': 'S368I',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label': 'S368I'},
                           {'serum': 'MZ4', 'virus': 'S368V',
                            'replicate': 'average', 'color': colorwheel[3],
                            'marker': m, 'label': 'S368V'}]
                          ),

                # row 5 left: ZKA64 versus WT, A333R, T315Y
                 (4, 0): ('ZKA64',
                          [{'serum': 'ZKA64', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'ZKA64', 'virus': 'A333R',
                            'replicate': 'average', 'color': colorwheel[4],
                            'marker': m, 'label': 'A333R'},
                           {'serum': 'ZKA64', 'virus': 'T315Y',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label': 'T315Y'}]
                          ),
                 # row 5 center: ZV67 versus WT, A310D, T315Y
                 (4, 1): ('ZV67',
                          [{'serum': 'ZV67', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'ZV67', 'virus': 'A310D',
                            'replicate': 'average', 'color': colorwheel[4],
                            'marker': m, 'label': 'A310D'},
                           {'serum': 'ZV67', 'virus': 'T315Y',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label': 'T315Y'}]
                          ),
                 # row 5 right: ZV67 versus WT, A333R, A333W
                 (4, 2): ('ZV67',
                          [{'serum': 'ZV67', 'virus': 'WT',
                            'replicate': 'average', 'color': colorwheel[0],
                            'marker': m, 'label': 'WT'},
                           {'serum': 'ZV67', 'virus': 'A333R',
                            'replicate': 'average', 'color': colorwheel[4],
                            'marker': m, 'label': 'A333R'},
                           {'serum': 'ZV67', 'virus': 'A333W',
                            'replicate': 'average', 'color': colorwheel[2],
                            'marker': m, 'label': 'A333W'}]
                          ),
                 },
                xlabel='concentration (ug/ml)',
                )
# Out:
# /Users/ckikawa/opt/miniconda3/lib/python3.9/site-packages/neutcurve/hillcurve.py:741: RuntimeWarning: invalid value encountered in power
#   return b + (t - b) / (1 + (c / m)**s)
# /Users/ckikawa/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
# For supplement, we might want to show all average curves
fig, axes = fits.plotAverages(xlabel='concentration (ug/ml)')

# %%
# We could also show viruses against multiple abs
fig, axes = fits.plotViruses(
                   xlabel='concentration (ug/ml)',
                   viruses=['WT', 'S7P', ],
                   sera=['C10', 'C8', 'SiGN3C'],
                   serum_to_color_marker={'C10': (colorwheel[0], 'o'),
                                         'C8': (colorwheel[1], 'o'),
                                         'SiGN3C': (colorwheel[2], 'o')})

# %%
# Finally we want to perform statistical tests on a selection of escape mutants
virus_lst = ['WT','T49D', 'S7P', 'E320S','K301H', 'G182D', 'S368N','A333W','A333R']
fits_subset = (
    fits.fitParams(average_only=False).loc[fits.fitParams(average_only=False)['virus'].isin(virus_lst)]
    .pivot(index = ['serum','virus'], columns = 'replicate', values = 'ic50')
    .reset_index()
    .rename(columns = {'1': 'replicate-1', '2': 'replicate-2',
                       '3': 'replicate-3', 'average': 'mean'})
    .rename_axis(None, axis=1)
    )

# Initialize empty list for p-values
p_values = []

for antibody in ab_dict:
    # Subset the subsetted dataframe on antibody
    fits_ab = fits_subset.query(f'serum == "{antibody}"')
    # Get wildtype IC50s to compare to
    WT_IC50 = fits_ab.query('virus == "WT"')[['replicate-1','replicate-2','replicate-3']].values.flatten()
    # Then iterate through each virus to get mut IC50s
    for v in fits_ab['virus']: 
        if v != 'WT':
            mutant_IC50 = (fits_ab.query(f'virus == "{v}"')
                           [['replicate-1','replicate-2','replicate-3']]
                           .values.flatten())
            # Calculate p-values with unpaired students t-test
            ttest = (ttest_ind(WT_IC50, mutant_IC50, equal_var=False)[1])
            # Calculate p-values with 1-way ANOVA
            ANOVA = (f_oneway(WT_IC50, mutant_IC50)[1])
        # Comparison of WT to WT should yield none-type
        elif v == 'WT':
            ttest = (np.nan)
            ANOVA = (np.nan)      
        p_values.append([antibody, v, ttest, ANOVA])

# Create p-value dataframe and merge with replicate IC50 data
pval_df = pd.DataFrame(p_values, columns=['serum','virus','ttest','ANOVA'])
fits_subset.merge(pval_df, how='inner', on=['serum','virus'])
# fits_subset.to_latex(buf = os.path.join(resultsdir, 'all_abs_IC50.tex'), index=False)
# Out:
# /var/folders/nt/tlltnd091f56l15648f2f0600000gp/T/ipykernel_69811/3622494369.py:27: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   ttest = (ttest_ind(WT_IC50, mutant_IC50, equal_var=False)[1])
# /var/folders/nt/tlltnd091f56l15648f2f0600000gp/T/ipykernel_69811/3622494369.py:27: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   ttest = (ttest_ind(WT_IC50, mutant_IC50, equal_var=False)[1])
#      serum  virus  replicate-1  replicate-2  replicate-3     mean     ttest     ANOVA
# 0      C10    S7P      0.02303      0.01253      0.01653  0.01824   0.02938   0.01118
# 1      C10   T49D      0.01184      0.01389     0.007511  0.01092   0.02766   0.01967
# 2      C10     WT     0.003252     0.004502    0.0006166 0.003196       NaN       NaN
# 3       C8    S7P        0.453       0.3576       0.5248   0.4515   0.01213 0.0008457
# 4       C8     WT      0.01022     0.008987     0.009424  0.00951       NaN       NaN
# 5      MZ4  G182D        7.976           10        6.196    8.926   0.01813  0.001848
# 6      MZ4  K301H       0.5049       0.7295       0.7668   0.7183   0.01503  0.001288
# 7      MZ4  S368N        6.315        3.248         6.63    5.259    0.0378   0.00751
# 8      MZ4     WT     0.009097      0.00549      0.00907 0.008337       NaN       NaN
# 9   SiGN3C  E320S       0.5299       0.1786       0.4597   0.3437    0.7579    0.7571
# 10  SiGN3C    S7P        1.012        1.112         0.65   0.9035   0.05177   0.04047
# 11  SiGN3C   T49D       0.8612        0.421      0.07575   0.3386    0.9466    0.9447
# 12  SiGN3C     WT       0.5857       0.2917       0.4268   0.4482       NaN       NaN
# 13   ZKA64  A333R           50           50           50       50 2.628e-08 4.145e-15
# 14   ZKA64     WT         0.16       0.1325       0.1414   0.1524       NaN       NaN
# 15    ZV67  A333R        2.426         5.67        1.261     2.36    0.1421   0.07754
# 16    ZV67  A333W           10           10           10       10 8.455e-09 4.289e-16
# 17    ZV67     WT     0.005677     0.004109     0.002493  0.00571       NaN       NaN

# %%
# Plots corresponding to the above subset
fig, axes = fits.plotSera(ncol = 3,
                          xlabel = 'concentration (ug/ml)',
                          viruses=virus_lst,
                          sera='all',
                          virus_to_color_marker={'WT': (colorwheel[0], 'o'),
                                                 'T49D': (colorwheel[1], 'o'),
                                                 'S7P': (colorwheel[2], 'o'),
                                                 'E320S': (colorwheel[3], 'o'),
                                                 'K301H': (colorwheel[3], 'o'), 
                                                 # Remove duplicate colors to move figure legend outside plots
                                                 'G182D': (colorwheel[4], 'o'),
                                                 'S368N': (colorwheel[5], 'o'),
                                                 'A333W': (colorwheel[6], 'o'),
                                                 'A333R': (colorwheel[7], 'o')
                                                }
                         )


neutfile = os.path.join(resultsdir, 'all_abs_neutcurves_Vero.pdf')
fig.savefig(neutfile, dpi='figure')
